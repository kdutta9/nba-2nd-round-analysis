# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
# url that we are scraping
base_url = "http://www.basketball-reference.com/draft/NBA_{year}.html"

# %%
draft_df = pd.DataFrame()

# %%
second_round_numbers = list(range(31,61))
second_round_numbers = [str(x) for x in second_round_numbers]
#second_round_numbers

# %%
for year in range(2004, 2015):  # for each year
    url = base_url.format(year=year)  # get the url
    
    html = urlopen(url)  # get the html
    soup = BeautifulSoup(html, 'html5lib') # create our BS object
    
    column_headers = [th.getText() for th in soup.findAll('tr', limit=2)[1].findAll('th')]
    column_headers.remove('Rk') #Rk does not get caught by player data
    
    # get our player data
    data_rows = soup.findAll('tr')[2:] 
    player_data = [[td.getText() for td in data_rows[i].findAll('td')] for i in range(len(data_rows))]
    
    #replace '' with 0 
    for i in player_data:
        i[:] = [0 if x=='' else x for x in i]
    
    #remove empty data
    counter = 0
    length = len(player_data)
    while(counter<length):
        if(player_data[counter]==[]):
            player_data.remove(player_data[counter])
            # as an element is removed
            # so decrease the length by 1
            length = length - 1  
            # run loop again to check element
            # at same index, when item removed 
            # next item will shift to the left 
            continue
        counter = counter + 1
    
    #only access 2nd rounders
    player_data = [x for x in player_data if x[0] in second_round_numbers]
    
    #print(second_round_data)
        
    # Turn yearly data into a DatFrame
    year_df = pd.DataFrame(player_data, columns=column_headers)
    # create and insert the Draft_Yr column
    year_df.insert(0, 'Draft Year', year)
    
    # Append to the big dataframe
    draft_df = draft_df.append(year_df, ignore_index=True)

# %%
# Convert data to proper data types
draft_df = draft_df.infer_objects()

# Get rid of the rows full of null values
draft_df = draft_df[draft_df.Player.notnull()]

# Replace NaNs with 0s
draft_df = draft_df.fillna(0)

# Rename Columns
draft_df.rename(columns={'WS/48':'WS_per_48'}, inplace=True)

# Change % symbol
draft_df.columns = draft_df.columns.str.replace('%', '_Perc')
# Add per_G to per game stats
draft_df.columns.values[15:19] = [draft_df.columns.values[15:19][col] + 
                                  "_per_G" for col in range(4)]

draft_df.infer_objects()
# Out:
#      Draft Year  Pk   Tm                  Player  \
# 0          2004  31  CHI          Jackson Vroman
# 1          2004  32  WAS        Peter John Ramos
# 2          2004  33  LAC         Lionel Chalmers
# 3          2004  34  ATL             Donta Smith
# 4          2004  35  SEA            Andre Emmett
# 5          2004  36  ORL           Antonio Burks
# 6          2004  37  ATL              Royal Ivey
# 7          2004  38  CHI             Chris Duhon
# 8          2004  39  TOR         Albert Miralles
# 9          2004  40  BOS             Justin Reed
# 10         2004  41  SEA             David Young
# 11         2004  42  ATL        Viktor Sanikidze
# 12         2004  43  NYK            Trevor Ariza
# 13         2004  44  NOH             Tim Pickett
# 14         2004  45  CHA        Bernard Robinson
# 15         2004  46  POR            Ha Seung-Jin
# 16         2004  47  MIA                Pape Sow
# 17         2004  48  SAC            Ricky Minard
# 18         2004  49  MEM          Sergei Lishouk
# 19         2004  50  DAL      Vassilis Spanoulis
# 20         2004  51  NJN        Christian Drejer
# 21         2004  52  SAS             Romain Sato
# 22         2004  53  MIA             Matt Freije
# 23         2004  54  DET         Rickey Paulding
# 24         2004  55  HOU             Luis Flores
# 25         2004  56  LAL          Marcus Douthit
# 26         2004  57  SAS         Sergei Karaulov
# 27         2004  58  MIN             Blake Stepp
# 28         2004  59  IND           Rashad Wright
# 29         2005  31  ATL        Salim Stoudamire
# ..          ...  ..  ...                     ...
# 299        2014  31  MIL           Damien Inglis
# 300        2014  32  PHI          K.J. McDaniels
# 301        2014  33  CLE              Joe Harris
# 302        2014  34  NYK        Cleanthony Early
# 303        2014  35  UTA          Jarnell Stokes
# 304        2014  36  MIL     Johnny O'Bryant III
# 305        2014  37  TOR         DeAndre Daniels
# 306        2014  38  DET       Spencer Dinwiddie
# 307        2014  39  PHI            Jerami Grant
# 308        2014  40  MIN      Glenn Robinson III
# 309        2014  41  DEN            Nikola Jokic
# 310        2014  42  HOU            Nick Johnson
# 311        2014  43  ATL          Walter Tavares
# 312        2014  44  MIN            Markel Brown
# 313        2014  45  CHH           Dwight Powell
# 314        2014  46  WAS         Jordan Clarkson
# 315        2014  47  PHI              Russ Smith
# 316        2014  48  MIL         Lamar Patterson
# 317        2014  49  CHI        Cameron Bairstow
# 318        2014  50  PHO              Alec Brown
# 319        2014  51  NYK  Thanasis Antetokounmpo
# 320        2014  52  PHI          Vasilije Micic
# 321        2014  53  MIN      Alessandro Gentile
# 322        2014  54  PHI        Nemanja Dangubic
# 323        2014  55  MIA          Semaj Christon
# 324        2014  56  DEN        Roy Devyn Marble
# 325        2014  57  IND          Louis Labeyrie
# 326        2014  58  SAS            Jordan McRae
# 327        2014  59  TOR           Xavier Thames
# 328        2014  60  SAS          Cory Jefferson
#
#                                     College Yrs     G     MP    PTS   TRB  \
# 0                     Iowa State University   2    87   1111    285   261
# 1                                         0   1     6     20     11     4
# 2                         Xavier University   1    36    433    111    31
# 3             Southeastern Illinois College   2    61    560    165    66
# 4                     Texas Tech University   2    14     73     20     8
# 5                     University of Memphis   2    81    789    186    49
# 6             University of Texas at Austin  10   492   6162   1641   557
# 7                           Duke University   9   606  15526   3946  1364
# 8                                         0   0     0      0      0     0
# 9                 University of Mississippi   3   136   1436    472   186
# 10        North Carolina Central University   0     0      0      0     0
# 11                                        0   0     0      0      0     0
# 12    University of California, Los Angeles  15  1011  30157  10792  4884
# 13                 Florida State University   0     0      0      0     0
# 14                   University of Michigan   3   128   1909    576   315
# 15                                        0   2    46    316     70    67
# 16   California State University, Fullerton   3    76    879    219   214
# 17                Morehead State University   0     0      0      0     0
# 18                                        0   0     0      0      0     0
# 19                                        0   1    31    272     85    22
# 20                    University of Florida   0     0      0      0     0
# 21                        Xavier University   0     0      0      0     0
# 22                    Vanderbilt University   2    42    588    133    85
# 23                   University of Missouri   0     0      0      0     0
# 24                        Manhattan College   1    16     77     35     3
# 25                       Providence College   0     0      0      0     0
# 26                                        0   0     0      0      0     0
# 27                       Gonzaga University   0     0      0      0     0
# 28                    University of Georgia   0     0      0      0     0
# 29                    University of Arizona   3   157   2672   1260   214
# ..                                      ...  ..   ...    ...    ...   ...
# 299                                       0   1    20    156     36    31
# 300                      Clemson University   3   148   2092    782   324
# 301                  University of Virginia   5   262   5914   2454   742
# 302                Wichita State University   2    56    801    241   123
# 303                 University of Tennessee   3    28    151     67    40
# 304              Louisiana State University   4   147   1684    509   352
# 305               University of Connecticut   0     0      0      0     0
# 306                  University of Colorado   5   253   6168   2785   654
# 307                     Syracuse University   5   383   9233   3369  1500
# 308                  University of Michigan   5   219   3144    956   461
# 309                                       0   4   308   8718   5006  2946
# 310                   University of Arizona   1    28    262     74    39
# 311                                       0   2    13    101     33    32
# 312               Oklahoma State University   3   113   1794    584   234
# 313                     Stanford University   5   331   5895   2491  1484
# 314                  University of Missouri   5   382  10527   5621  1237
# 315                University of Louisville   2    27    131     53    15
# 316                University of Pittsburgh   2    40    435     93    57
# 317                University of New Mexico   2    36    167     44    36
# 318       University of Wisconsin-Green Bay   0     0      0      0     0
# 319                                       0   1     2      6      6     1
# 320                                       0   0     0      0      0     0
# 321                                       0   0     0      0      0     0
# 322                                       0   0     0      0      0     0
# 323                       Xavier University   1    64    973    183    87
# 324                      University of Iowa   2    44    457     97    69
# 325                                       0   0     0      0      0     0
# 326                 University of Tennessee   3    86    912    420   101
# 327              San Diego State University   0     0      0      0     0
# 328                       Baylor University   2    58    581    205   161
#
#      ...  3P_Perc FT_Perc    MP PTS_per_G TRB_per_G AST_per_G WS_per_G  \
# 0    ...     .000    .580  12.8       3.3       3.0       0.6      0.0
# 1    ...        0    .500   3.3       1.8       0.7       0.0      0.0
# 2    ...     .245    .625  12.0       3.1       0.9       1.4     -0.2
# 3    ...     .308    .650   9.2       2.7       1.1       0.8      0.5
# 4    ...     .000    .615   5.2       1.4       0.6       0.1      0.1
# 5    ...     .235    .571   9.7       2.3       0.6       1.3      0.1
# 6    ...     .361    .706  12.5       3.3       1.1       1.0      4.5
# 7    ...     .363    .784  25.6       6.5       2.3       4.4     25.0
# 8    ...        0       0     0         0         0         0        0
# 9    ...     .000    .752  10.6       3.5       1.4       0.5      0.5
# 10   ...        0       0     0         0         0         0        0
# 11   ...        0       0     0         0         0         0        0
# 12   ...     .351    .728  29.8      10.7       4.8       2.2     60.0
# 13   ...        0       0     0         0         0         0        0
# 14   ...     .161    .786  14.9       4.5       2.5       1.0      2.0
# 15   ...        0    .500   6.9       1.5       1.5       0.1     -0.2
# 16   ...        0    .678  11.6       2.9       2.8       0.2      0.8
# 17   ...        0       0     0         0         0         0        0
# 18   ...        0       0     0         0         0         0        0
# 19   ...     .172    .810   8.8       2.7       0.7       0.9     -0.1
# 20   ...        0       0     0         0         0         0        0
# 21   ...        0       0     0         0         0         0        0
# 22   ...     .224    .714  14.0       3.2       2.0       0.6     -0.6
# 23   ...        0       0     0         0         0         0        0
# 24   ...     .500   1.000   4.8       2.2       0.2       0.7      0.0
# 25   ...        0       0     0         0         0         0        0
# 26   ...        0       0     0         0         0         0        0
# 27   ...        0       0     0         0         0         0        0
# 28   ...        0       0     0         0         0         0        0
# 29   ...     .366    .882  17.0       8.0       1.4       1.0      2.2
# ..   ...      ...     ...   ...       ...       ...       ...      ...
# 299  ...     .231    .875   7.8       1.8       1.6       0.5     -0.1
# 300  ...     .290    .776  14.1       5.3       2.2       0.6      1.3
# 301  ...     .427    .797  22.6       9.4       2.8       1.5     10.4
# 302  ...     .263    .750  14.3       4.3       2.2       0.8     -0.6
# 303  ...        0    .531   5.4       2.4       1.4       0.3      0.6
# 304  ...     .360    .663  11.5       3.5       2.4       0.5      0.2
# 305  ...        0       0     0         0         0         0        0
# 306  ...     .323    .801  24.4      11.0       2.6       4.5     13.5
# 307  ...     .334    .654  24.1       8.8       3.9       1.0     18.2
# 308  ...     .361    .726  14.4       4.4       2.1       0.6      4.7
# 309  ...     .345    .828  28.3      16.3       9.6       5.1     38.9
# 310  ...     .238    .680   9.4       2.6       1.4       0.4     -0.1
# 311  ...        0    .273   7.8       2.5       2.5       0.3      0.2
# 312  ...     .295    .781  15.9       5.2       2.1       1.2      1.1
# 313  ...     .298    .750  17.8       7.5       4.5       0.9     22.4
# 314  ...     .335    .815  27.6      14.7       3.2       2.7     10.5
# 315  ...     .188    .769   4.9       2.0       0.6       0.7     -0.2
# 316  ...     .236    .720  10.9       2.3       1.4       1.1      0.1
# 317  ...     .200    .846   4.6       1.2       1.0       0.2     -0.1
# 318  ...        0       0     0         0         0         0        0
# 319  ...     .000       0   3.0       3.0       0.5       0.0      0.0
# 320  ...        0       0     0         0         0         0        0
# 321  ...        0       0     0         0         0         0        0
# 322  ...        0       0     0         0         0         0        0
# 323  ...     .190    .548  15.2       2.9       1.4       2.0      0.1
# 324  ...     .222    .375  10.4       2.2       1.6       0.7     -0.3
# 325  ...        0       0     0         0         0         0        0
# 326  ...     .352    .784  10.6       4.9       1.2       0.9      1.0
# 327  ...        0       0     0         0         0         0        0
# 328  ...     .125    .583  10.0       3.5       2.8       0.3      0.9
#
#     WS_per_48    BPM  VORP
# 0        .001   -3.9  -0.5
# 1       -.108  -18.3  -0.1
# 2       -.025   -6.3  -0.5
# 3        .043   -3.2  -0.2
# 4        .040   -6.8  -0.1
# 5        .004   -6.6  -0.9
# 6        .035   -3.8  -2.8
# 7        .077   -1.5   2.0
# 8           0      0     0
# 9        .016   -5.9  -1.4
# 10          0      0     0
# 11          0      0     0
# 12       .095    1.5  26.3
# 13          0      0     0
# 14       .049   -2.0   0.0
# 15      -.029   -8.3  -0.5
# 16       .044   -4.8  -0.6
# 17          0      0     0
# 18          0      0     0
# 19      -.010   -6.7  -0.3
# 20          0      0     0
# 21          0      0     0
# 22      -.047   -6.3  -0.6
# 23          0      0     0
# 24      -.020   -9.6  -0.1
# 25          0      0     0
# 26          0      0     0
# 27          0      0     0
# 28          0      0     0
# 29       .040   -5.1  -2.1
# ..        ...    ...   ...
# 299     -.024   -6.4  -0.2
# 300      .030   -3.3  -0.7
# 301      .085   -0.5   2.2
# 302     -.039   -5.7  -0.8
# 303      .202    1.0   0.1
# 304      .006   -6.4  -1.9
# 305         0      0     0
# 306      .105   -0.6   2.1
# 307      .095   -1.1   2.0
# 308      .072   -2.6  -0.5
# 309      .214    7.6  21.2
# 310     -.020   -7.3  -0.3
# 311      .118   -0.6   0.0
# 312      .029   -2.8  -0.4
# 313      .182    2.1   6.1
# 314      .048   -1.8   0.6
# 315     -.068   -6.4  -0.1
# 316      .006   -5.5  -0.4
# 317     -.021   -7.7  -0.2
# 318         0      0     0
# 319      .291   -4.1   0.0
# 320         0      0     0
# 321         0      0     0
# 322         0      0     0
# 323      .006   -6.3  -1.1
# 324     -.028   -5.0  -0.3
# 325         0      0     0
# 326      .051   -5.0  -0.7
# 327         0      0     0
# 328      .071   -4.6  -0.4
#
# [329 rows x 22 columns]
